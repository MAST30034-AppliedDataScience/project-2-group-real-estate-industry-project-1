# %%
import os
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import folium
from folium.plugins import MarkerCluster

# %%
# Create folder to save dataset
base_dir = '../../data/'
landing_dir = os.path.join(base_dir, 'landing')
raw_dir = os.path.join(base_dir, 'raw')

if not os.path.exists(base_dir):
    os.makedirs(base_dir)


subfolder = 'Supermarkets'


if not os.path.exists(os.path.join(raw_dir, subfolder)):
    os.makedirs(os.path.join(raw_dir, subfolder))

# %%
df = pd.read_csv(f"{landing_dir}/{subfolder}/supermarkets_with_location.csv")

# %%
df.head(5)
# Out:
#   Supermarket Name                                            Address  \
# 0             Aldi                       8 Franklin Street, Melbourne
# 1            Coles                      2 Elizabeth Street, Melbourne
# 2            Coles  Melbourne Central, 183-201 La Trobe Street, Me...
# 3  Friendly Grocer              Shop 1, 360 Collins Street, Melbourne
# 4              IGA                      470 Collins Street, Melbourne
#
#       Suburb Postcode   Latitude   Longitude
# 0  Melbourne     3000 -37.807383  144.962439
# 1  Melbourne     3089 -37.673315  145.155278
# 2  Melbourne     3000 -37.808785  144.966817
# 3  Melbourne     3429 -37.581855  144.700634
# 4  Melbourne     3000 -37.817580  144.958513

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Supermarket Name  173 non-null    object
#  1   Address           173 non-null    object
#  2   Suburb            173 non-null    object
#  3   Postcode          172 non-null    object
#  4   Latitude          172 non-null    float64
#  5   Longitude         172 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 8.2+ KB

# %%
missing_postcode_data = df[df['Postcode'].isnull()]
missing_postcode_data
# Out:
#    Supermarket Name                                   Address   Suburb  \
# 29              IGA  Alira Village, 36 Adakite Drive, Berwick  Berwick
#
#    Postcode  Latitude  Longitude
# 29      NaN       NaN        NaN

# %%
# Manually searched for the location information corresponding to "36 Adakite Dr, Berwick" and filling it in for the missing value
df.loc[(df['Address'] == 'Alira Village, 36 Adakite Drive, Berwick') & df['Postcode'].isnull(), 'Postcode'] = '3806'
df.loc[(df['Address'] == 'Alira Village, 36 Adakite Drive, Berwick') & df['Latitude'].isnull(), 'Latitude'] = -38.048359
df.loc[(df['Address'] == 'Alira Village, 36 Adakite Drive, Berwick') & df['Longitude'].isnull(), 'Longitude'] = 145.320480

# Display the updated data
df
# Out:
#     Supermarket Name                                            Address  \
# 0               Aldi                       8 Franklin Street, Melbourne
# 1              Coles                      2 Elizabeth Street, Melbourne
# 2              Coles  Melbourne Central, 183-201 La Trobe Street, Me...
# 3    Friendly Grocer              Shop 1, 360 Collins Street, Melbourne
# 4                IGA                      470 Collins Street, Melbourne
# ..               ...                                                ...
# 168              IGA                       167-179 Shaws Road, Werribee
# 169       Woolworths                          2 Watton Street, Werribee
# 170       Woolworths    Pacific Werribee, Heaths Road, Hoppers Crossing
# 171            Coles                    29 Douglas Parade, Williamstown
# 172       Woolworths               71 Kororoit Creek Road, Williamstown
#
#                Suburb Postcode   Latitude   Longitude
# 0           Melbourne     3000 -37.807383  144.962439
# 1           Melbourne     3089 -37.673315  145.155278
# 2           Melbourne     3000 -37.808785  144.966817
# 3           Melbourne     3429 -37.581855  144.700634
# 4           Melbourne     3000 -37.817580  144.958513
# ..                ...      ...        ...         ...
# 168          Werribee     3030 -37.890070  144.662180
# 169          Werribee     3030 -37.901620  144.660788
# 170  Hoppers Crossing     3029 -37.874674  144.679771
# 171      Williamstown     3016 -37.857626  144.897416
# 172      Williamstown     3016 -37.857467  144.882612
#
# [173 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Supermarket Name  173 non-null    object
#  1   Address           173 non-null    object
#  2   Suburb            173 non-null    object
#  3   Postcode          173 non-null    object
#  4   Latitude          173 non-null    float64
#  5   Longitude         173 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 8.2+ KB

# %%
# save data
output_file_path = f"{raw_dir}/{subfolder}/supermarkets_info.csv"
df.to_csv(output_file_path, index=False)

# %%
# Create a geometry column from latitude and longitude
geometry = [Point(xy) for xy in zip(df['Longitude'], df['Latitude'])]

# Create a GeoDataFrame
gdf = gpd.GeoDataFrame(df, geometry=geometry)

# Create a folium map object, centered at a location (e.g., Melbourne)
m = folium.Map(location=[-37.8136, 144.9631], zoom_start=12)  # Adjust the zoom level as needed

# Create a MarkerCluster object
marker_cluster = MarkerCluster().add_to(m)

# Add markers to the cluster
for _, row in gdf.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['Supermarket Name']} - {row['Suburb']}",
        tooltip=row['Suburb']
    ).add_to(marker_cluster)

m

# Save the map to an HTML file for viewing in a web browser
# m.save("supermarkets_map_with_cluster.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63f2517e93626756be7e70515c158270 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63f2517e93626756be7e70515c158270&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63f2517e93626756be7e70515c158270 = L.map(
#                 &quot;map_63f2517e93626756be7e70515c158270&quot;,
#                 {
#                     center: [-37.8136, 144.9631],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b63c5cf48f5c3181656228a7b42435f7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b63c5cf48f5c3181656228a7b42435f7.addTo(map_63f2517e93626756be7e70515c158270);
#
#
#             var marker_cluster_5b4f8406d4db9dddb86e09aaf268e461 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_1798ec68eb289505c7610bc4de15bdc4 = L.marker(
#                 [-37.8073827, 144.9624394],
#                 {}
#             ).addTo(marker_cluster_5b4f8406d4db9dddb86e09aaf268e461);
#
#
#         var popup_a11f7fb25ebc94a2f9c2dfcd40e64860 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_110bac287b67bac7cf71550aa1cc50ce = $(`&lt;div id=&quot;html_110bac287b67bac7cf71550aa1cc50ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aldi - Melbourne&lt;/div&gt;`)[0];
#                 popup_a11f7fb25ebc94a2f9c2dfcd40e64860.setContent(html_110bac287b67bac7cf71550aa1cc50ce);
#
#
#
#         marker_1798ec68eb289505c7610bc4de15bdc4.bindPopup(popup_a11f7fb25ebc94a2f9c2dfcd40e64860)
#         ;
#
#
#
#
#             marker_1798ec68eb289505c7610bc4de15bdc4.bindTooltip(
#                 `&lt;div&gt;
#                      Melbourne
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_01d11eb9b3e47262407a49903f624717 = L.marker(
#                 [-37.67331455, 145.1552776754374],
#                 {}
#             ).addTo(marker_cluster_5b4f8406d4db9dddb86e09aaf268e461);
#
#
#         var popup_a8f45fb2a55ffb7dcd008943ce324aa5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6e242aaf2d1330b1396e6649d5890f39 = $(`&lt;div id=&quot;html_6e242aaf2d1330b1396e6649d5890f39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coles - Melbourne&lt;/div&gt;`)[0];
#                 popup_a8f45fb2a55ffb7dcd008943ce324aa5.setContent(html_6e242aaf2d1330b1396e6649d5890f39);
#
#
#
#         marker_01d11eb9b3e47262407a49903f624717.bindPopup(popup_a8f45fb2a55ffb7dcd008943ce324aa5)
#         ;
#
#
#
#
#             marker_01d11eb9b3e47262407a49903f624717.bindTooltip(
#                 `&lt;div&gt;
#                      Melbourne
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7957598ca1e3eb72af2a41fb1555389d = L.marker(
#                 [-37.8087845, 144.9668175],
#                 {}
#             ).addTo(marker_cluster_5b4f8406d4db9dddb86e09aaf268e461);
#
#
#         var popup_50db7d3a0af88af4615dc4c5b5645d84 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_06f2b0aa6d0eab371c1dabb633fcef90 = $(`&lt;div id=&quot;html_06f2b0aa6d0eab371c1dabb633fcef90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coles - Melbourne&lt;/div&gt;`)[0];
#                 popup_50db7d3a0af88af4615dc4c5b5645d84.setContent(html_06f2b0aa6d0eab371c1dabb633fcef90);
#
#
#
#         marker_7957598ca1e3eb72af2a41fb1555389d.bindPopup(popup_50db7d3a0af88af4615dc4c5b5645d84)
#         ;
#
#
#
#
#             marker_7957598ca1e3eb72af2a41fb1555389d.bindTooltip(
#                 `&lt;div&gt;
#                      Melbourne
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d0da8373643067e1068417228570f57d = L.marker(
#                 [-37.5818548, 144.700634],
#                 {}
#             ).addTo(marker_cluster_5b4f8406d4db9dddb86e09aaf268e461);
#
#
#         var popup_aa15c7fca92d201190b1cf1994f1bbc5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_94ea3610e2fcf97b0a52dab7143a259f = $(`&lt;div id=&quot;html_94ea3610e2fcf97
