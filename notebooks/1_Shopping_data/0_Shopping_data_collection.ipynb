# %%
import os
import re
import requests
from bs4 import BeautifulSoup
import csv
from geopy.geocoders import Nominatim
import time
import pandas as pd

# %%
# Create folder to save dataset
base_dir = '../../data/'
landing_dir = os.path.join(base_dir, 'landing')

if not os.path.exists(base_dir):
    os.makedirs(base_dir)

if not os.path.exists(landing_dir):
    os.makedirs(landing_dir)

subfolder = 'Supermarkets'

if not os.path.exists(os.path.join(landing_dir, subfolder)):
    os.makedirs(os.path.join(landing_dir, subfolder))

# %%
# Extract links to different regions from the homepage
def get_region_urls(home_url):
    response = requests.get(home_url)
    if response.status_code != 200:
        print(f"Could not access {home_url}")
        return []
    
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Find all region links
    region_links = soup.find_all('a', class_='stretched-link')
    
    base_url = "https://www.travelvictoria.com.au"
    region_urls = [base_url + link['href'] for link in region_links]
    
    return region_urls

# Get the supermarket page URL for each region
def get_supermarket_url(region_url):
    response = requests.get(region_url)
    if response.status_code != 200:
        print(f"Could not access {region_url}")
        return None
    
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Look for the link that contains 'supermarkets'
    for link in soup.find_all('a', href=True):
        if "supermarkets" in link['href']:
            return "https://www.travelvictoria.com.au" + link['href']
    
    return None

# Function to extract Suburb from the address
def extract_suburb_from_address(address):
    # Assuming the suburb is the last part of the address, match it with regex
    match = re.search(r',\s*([^,]+)$', address)
    if match:
        return match.group(1).strip()
    return None

# Scrape supermarket names, addresses, and extract suburb from the address
def get_supermarkets_info(supermarket_url):
    response = requests.get(supermarket_url)
    if response.status_code != 200:
        print(f"Could not access {supermarket_url}")
        return []
    
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Find supermarket names and addresses
    supermarkets = []
    
    # Print the page title to ensure we are on the correct page
    print(f"Visiting supermarket page: {supermarket_url}")
    print(f"Page Title: {soup.title.string.strip()}")
    
    # Find all supermarket entries
    supermarket_entries = soup.find_all('div', class_='row')
    
    if not supermarket_entries:
        print(f"No supermarket entries found on {supermarket_url}")
        return supermarkets
    
    # Skip the first entry, assuming it's always the region name
    for idx, entry in enumerate(supermarket_entries):
        # Skip the first entry (region name)
        if idx == 0:
            continue
        
        # Select only <h5> tags, ensuring it's the supermarket name
        name_element = entry.find('h5')
        if not name_element:
            continue
        
        name = name_element.get_text(strip=True)
        
        # Find the supermarket address (in div class="col-sm-8 col-md-6 col-lg-9")
        address_element = entry.find('div', class_='col-sm-8 col-md-6 col-lg-9')
        
        # Skip entries without an address
        if not address_element:
            print(f"Skipping entry without address: {name}")
            continue
        
        # Filter out strings containing "Show on map" and exclude invalid entries
        addresses = [div.strip() for div in address_element.stripped_strings if 'Show on map' not in div]
        
        # Ensure valid pairing of name and address
        if name and len(addresses) > 0:
            for address in addresses:
                suburb = extract_suburb_from_address(address)  # Extract Suburb from the address
                print(f"Found Supermarket: Name={name}, Address={address}, Suburb={suburb}")
                supermarkets.append((name, address, suburb))
    
    return supermarkets

# Loop through all regions and scrape supermarket info
def scrape_all_regions(region_urls):
    all_supermarkets_info = []

    for region_url in region_urls:
        supermarket_url = get_supermarket_url(region_url)
        if supermarket_url:
            print(f"Found supermarket page: {supermarket_url}")
            supermarkets_info = get_supermarkets_info(supermarket_url)
            all_supermarkets_info.extend(supermarkets_info)
        else:
            print(f"No supermarket page for {region_url}")
    
    return all_supermarkets_info

# Save all supermarket information to a Parquet file in 'data/landing/supermarkets/'
def save_supermarkets_to_parquet(supermarkets_info, filename):
    # Define the folder path where the file will be saved
    folder_path = "../../data/landing/Supermarkets"
    
    # Define the full path to the file
    file_path = os.path.join(folder_path, filename)
    
    # Convert the list of supermarkets into a DataFrame
    df = pd.DataFrame(supermarkets_info, columns=["Supermarket Name", "Address", "Suburb"])
    
    # Save the DataFrame as a Parquet file
    df.to_parquet(file_path, index=False, engine='pyarrow')
    
    print(f"Supermarkets information has been saved to '{file_path}'")

# Homepage URL
home_url = "https://www.travelvictoria.com.au/regions/melbourne/"

# Get all region URLs from the homepage
region_urls = get_region_urls(home_url)

# Scrape supermarket info for all regions
all_supermarkets_info = scrape_all_regions(region_urls)

# Save supermarket info to the specific directory
save_supermarkets_to_parquet(all_supermarkets_info, "supermarkets_info.parquet")
# Out:
# Found supermarket page: https://www.travelvictoria.com.au/melbourne/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/melbourne/supermarkets/
# Page Title: Melbourne CBD supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Aldi, Address=8 Franklin Street, Melbourne, Suburb=Melbourne
# Found Supermarket: Name=Coles, Address=2 Elizabeth Street, Melbourne, Suburb=Melbourne
# Found Supermarket: Name=Coles, Address=Melbourne Central, 183-201 La Trobe Street, Melbourne, Suburb=Melbourne
# Found Supermarket: Name=Friendly Grocer, Address=Shop 1, 360 Collins Street, Melbourne, Suburb=Melbourne
# Found Supermarket: Name=IGA, Address=470 Collins Street, Melbourne, Suburb=Melbourne
# Found Supermarket: Name=IGA, Address=19 Commercial Road, Melbourne, Suburb=Melbourne
# Found Supermarket: Name=IGA, Address=333 Exhibition Street, Melbourne, Suburb=Melbourne
# Found Supermarket: Name=IGA, Address=84 Flinders Street, Melbourne, Suburb=Melbourne
# Found Supermarket: Name=IGA, Address=35-41 Lonsdale Street, Melbourne, Suburb=Melbourne
# Found Supermarket: Name=IGA, Address=85 Queen Street, Melbourne, Suburb=Melbourne
# Found Supermarket: Name=Woolworths, Address=600 Bourke Street, Melbourne, Suburb=Melbourne
# Found Supermarket: Name=Woolworths, Address=60 Elizabeth Street, Melbourne, Suburb=Melbourne
# Found Supermarket: Name=Woolworths, Address=388 Elizabeth Street, Melbourne, Suburb=Melbourne
# Found Supermarket: Name=Woolworths, Address=611 Elizabeth Street, Melbourne, Suburb=Melbourne
# Found Supermarket: Name=Woolworths, Address=222 Exhibition Street, Melbourne, Suburb=Melbourne
# Found Supermarket: Name=Woolworths, Address=262 Flinders Street, Melbourne, Suburb=Melbourne
# Found Supermarket: Name=Woolworths, Address=QV, 210 Lonsdale Street, Melbourne, Suburb=Melbourne
# Found Supermarket: Name=Woolworths, Address=374 Queen Street, Melbourne, Suburb=Melbourne
# Found supermarket page: https://www.travelvictoria.com.au/albertpark/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/albertpark/supermarkets/
# Page Title: Albert Park supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Albert Park Supermarket, Address=189 Victoria Avenue, Albert Park, Suburb=Albert Park
# Found Supermarket: Name=FoodWorks, Address=133 Dundas Place, Albert Park, Suburb=Albert Park
# Found Supermarket: Name=IGA, Address=163 Mills Street, Albert Park, Suburb=Albert Park
# Found Supermarket: Name=Woolworths, Address=95-97 Dundas Place, Albert Park, Suburb=Albert Park
# Found supermarket page: https://www.travelvictoria.com.au/beaumaris/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/beaumaris/supermarkets/
# Page Title: Beaumaris supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=FoodWorks, Address=346-348 Balcombe Road, Beaumaris, Suburb=Beaumaris
# Found Supermarket: Name=FoodWorks, Address=7A Keys Street, Beaumaris, Suburb=Beaumaris
# Found Supermarket: Name=IGA, Address=6-12 South Concourse, Beaumaris, Suburb=Beaumaris
# Found supermarket page: https://www.travelvictoria.com.au/berwick/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/berwick/supermarkets/
# Page Title: Berwick supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Aldi, Address=Eden Rise, 1 O'Shea Road, Berwick, Suburb=Berwick
# Found Supermarket: Name=Coles, Address=2 Richardson Grove, Berwick, Suburb=Berwick
# Found Supermarket: Name=Coles, Address=Eden Rise, 1 O'Shea Road, Berwick, Suburb=Berwick
# Found Supermarket: Name=Coles, Address=Parkhill Plaza, 215-225 Parkhill Drive, Berwick, Suburb=Berwick
# Found Supermarket: Name=IGA, Address=Alira Village, 36 Adakite Drive, Berwick, Suburb=Berwick
# Found Supermarket: Name=Woolworths, Address=Berwick Marketplace, 1-9 Lyall Road, Berwick, Suburb=Berwick
# Found supermarket page: https://www.travelvictoria.com.au/brighton/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/brighton/supermarkets/
# Page Title: Brighton supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Coles, Address=26-34 Church Street, Brighton, Suburb=Brighton
# Found Supermarket: Name=Coles, Address=380 Bay Street, Brighton, Suburb=Brighton
# Found Supermarket: Name=Go To Grocer, Address=116-122 Were Street, Brighton, Suburb=Brighton
# Found Supermarket: Name=IGA, Address=10 Cochrane Street, Brighton, Suburb=Brighton
# Found Supermarket: Name=IGA, Address=765A Hawthorn Road, Brighton East, Suburb=Brighton East
# Found Supermarket: Name=IGA, Address=566 Hawthorn Road, Caulfield South, Suburb=Caulfield South
# Found Supermarket: Name=Woolworths, Address=104 Church Street, Brighton, Suburb=Brighton
# Found supermarket page: https://www.travelvictoria.com.au/brunswick/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/brunswick/supermarkets/
# Page Title: Brunswick supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Aldi, Address=292-298 Sydney Road, Brunswick, Suburb=Brunswick
# Found Supermarket: Name=Coles, Address=Barkly Square, 90-106 Sydney Road, Brunswick, Suburb=Brunswick
# Found Supermarket: Name=Coles, Address=127-137 Nicholson Street, Brunswick East, Suburb=Brunswick East
# Found Supermarket: Name=Coles, Address=Union Square, 190 Union Street, Brunswick West, Suburb=Brunswick West
# Found Supermarket: Name=FoodWorks, Address=870 Sydney Road, Brunswick, Suburb=Brunswick
# Found Supermarket: Name=FoodWorks, Address=474 Lygon Street, Brunswick East, Suburb=Brunswick East
# Found Supermarket: Name=FoodWorks, Address=52 Melville Road, Brunswick West, Suburb=Brunswick West
# Found Supermarket: Name=Friendly Grocer, Address=25 Nicholson Street, Brunswick East, Suburb=Brunswick East
# Found Supermarket: Name=IGA, Address=1-9 Lygon Street, Brunswick, Suburb=Brunswick
# Found Supermarket: Name=IGA, Address=614 Sydney Road, Brunswick, Suburb=Brunswick
# Found Supermarket: Name=IGA, Address=21 Brunswick Road, Brunswick East, Suburb=Brunswick East
# Found Supermarket: Name=IGA, Address=326-328 Lygon Street, Brunswick East, Suburb=Brunswick East
# Found Supermarket: Name=IGA, Address=360 Moreland Road, Brunswick West, Suburb=Brunswick West
# Found Supermarket: Name=IGA, Address=2-6 Olive York Way, Brunswick West, Suburb=Brunswick West
# Found Supermarket: Name=Woolworths, Address=300-304 Albert Street, Brunswick, Suburb=Brunswick
# Found Supermarket: Name=Woolworths, Address=Barkly Square, 90-106 Sydney Road, Brunswick, Suburb=Brunswick
# Found Supermarket: Name=Woolworths, Address=808 Sydney Road, Brunswick, Suburb=Brunswick
# Found supermarket page: https://www.travelvictoria.com.au/carlton/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/carlton/supermarkets/
# Page Title: Carlton supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=FoodWorks, Address=799 Nicholson Street, Carlton North, Suburb=Carlton North
# Found Supermarket: Name=IGA, Address=109 Lygon Street, Carlton, Suburb=Carlton
# Found Supermarket: Name=Woolworths, Address=Lygon Court, 368-384 Lygon Street, Carlton, Suburb=Carlton
# Found supermarket page: https://www.travelvictoria.com.au/chelsea/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/chelsea/supermarkets/
# Page Title: Chelsea supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=IGA, Address=199 Thames Promenade, Chelsea Heights, Suburb=Chelsea Heights
# Found Supermarket: Name=Woolworths, Address=31-33 Bath Street, Chelsea, Suburb=Chelsea
# Found supermarket page: https://www.travelvictoria.com.au/cranbourne/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/cranbourne/supermarkets/
# Page Title: Cranbourne supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Aldi, Address=14-20 Bakewell Street, Cranbourne, Suburb=Cranbourne
# Found Supermarket: Name=Aldi, Address=Hunt Club Village, 1 Linsell Boulevard, Cranbourne East, Suburb=Cranbourne East
# Found Supermarket: Name=Aldi, Address=51 Hamersley Drive, Clyde North, Suburb=Clyde North
# Found Supermarket: Name=Aldi, Address=Marriott Waters, 10-18 Society Avenue, Lyndhurst, Suburb=Lyndhurst
# Found Supermarket: Name=Coles, Address=Cranbourne Park Shopping Centre, High Street, Cranbourne, Suburb=Cranbourne
# Found Supermarket: Name=Coles, Address=Springhill, 1370 Thompsons Road, Cranbourne, Suburb=Cranbourne
# Found Supermarket: Name=Coles, Address=95 Monahans Road, Cranbourne West, Suburb=Cranbourne West
# Found Supermarket: Name=Coles, Address=Botanic Ridge Village, 10 Hummingbird Drive, Botanic Ridge, Suburb=Botanic Ridge
# Found Supermarket: Name=Coles, Address=Shopping On Clyde, 280 Berwick - Cranbourne Road, Clyde, Suburb=Clyde
# Found Supermarket: Name=IGA, Address=Eve Central, 2-10 William Thwaites Boulevard, Cranbourne North, Suburb=Cranbourne North
# Found Supermarket: Name=IGA, Address=Clarinda Village, 85 Everlasting Boulevard, Cranbourne West, Suburb=Cranbourne West
# Found Supermarket: Name=Woolworths, Address=Hunt Club Village, 1 Linsell Boulevard, Cranbourne East, Suburb=Cranbourne East
# Found Supermarket: Name=Woolworths, Address=The Avenue Village, 20 Linden Tree Way, Cranbourne North, Suburb=Cranbourne North
# Found Supermarket: Name=Woolworths, Address=Thompson Parkway, 1085 South Gippsland Highway, Cranbourne North, Suburb=Cranbourne North
# Found Supermarket: Name=Woolworths, Address=19 Strathlea Drive, Cranbourne West, Suburb=Cranbourne West
# Found Supermarket: Name=Woolworths, Address=Selandra Rise, 2 Selandra Boulevard, Clyde North, Suburb=Clyde North
# Found Supermarket: Name=Woolworths, Address=Marriott Waters, 10-18 Society Avenue, Lyndhurst, Suburb=Lyndhurst
# Found supermarket page: https://www.travelvictoria.com.au/croydon/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/croydon/supermarkets/
# Page Title: Croydon supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Aldi, Address=Croydon Central, 5 Kent Avenue, Croydon, Suburb=Croydon
# Found Supermarket: Name=Coles, Address=Croydon Central, 15 Kent Avenue, Croydon, Suburb=Croydon
# Found Supermarket: Name=Coles, Address=434 Maroondah Highway, Croydon, Suburb=Croydon
# Found Supermarket: Name=Coles, Address=401-415 Maroondah Highway, Croydon North, Suburb=Croydon North
# Found Supermarket: Name=IGA, Address=13 The Mall, Croydon South, Suburb=Croydon South
# Found Supermarket: Name=Woolworths, Address=Arndale Civic, 224-238 Mount Dandenong Road, Croydon, Suburb=Croydon
# Found supermarket page: https://www.travelvictoria.com.au/dandenong/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/dandenong/supermarkets/
# Page Title: Dandenong supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Aldi, Address=Dandenong Square, 23-55 McCrae Street, Dandenong, Suburb=Dandenong
# Found Supermarket: Name=Coles, Address=Dandenong Square, 23-55 McCrae Street, Dandenong, Suburb=Dandenong
# Found Supermarket: Name=Coles, Address=23-26 Princes Highway, Dandenong, Suburb=Dandenong
# Found Supermarket: Name=FoodWorks, Address=42-44 Brady Road, Dandenong North, Suburb=Dandenong North
# Found Supermarket: Name=FoodWorks, Address=52-54 Menzies Avenue, Dandenong North, Suburb=Dandenong North
# Found Supermarket: Name=IGA, Address=78-84 Hemmings Street, Dandenong, Suburb=Dandenong
# Found Supermarket: Name=Woolworths, Address=1-3 Gladstone Road, Dandenong, Suburb=Dandenong
# Found Supermarket: Name=Woolworths, Address=Dandenong Square, 23-55 McCrae Street, Dandenong, Suburb=Dandenong
# Found Supermarket: Name=Woolworths, Address=14 Hartnett Way, Dandenong South, Suburb=Dandenong South
# Found supermarket page: https://www.travelvictoria.com.au/docklands/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/docklands/supermarkets/
# Page Title: Docklands supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Coles, Address=Spencer Outlet Centre, 201 Spencer Street, Docklands, Suburb=Docklands
# Found Supermarket: Name=Costco, Address=381 Footscray Road, Docklands, Suburb=Docklands
# Found Supermarket: Name=IGA, Address=20 Rakaia Way, Docklands, Suburb=Docklands
# Found Supermarket: Name=IGA, Address=54 River Esplanade, Docklands, Suburb=Docklands
# Found Supermarket: Name=Woolworths, Address=Collins Square, 727 Collins Street, Docklands, Suburb=Docklands
# Found Supermarket: Name=Woolworths, Address=63-93 Merchant Street, Docklands, Suburb=Docklands
# Found Supermarket: Name=Woolworths, Address=Southern Cross Station, 99 Spencer Street, Docklands, Suburb=Docklands
# Found Supermarket: Name=Woolworths, Address=The District Docklands, 90 Waterfront Way, Docklands, Suburb=Docklands
# Found supermarket page: https://www.travelvictoria.com.au/eastmelbourne/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/eastmelbourne/supermarkets/
# Page Title: East Melbourne supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=IGA, Address=416-446 Victoria Parade, East Melbourne, Suburb=East Melbourne
# Found supermarket page: https://www.travelvictoria.com.au/elwood/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/elwood/supermarkets/
# Page Title: Elwood supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=FoodWorks, Address=109 Ormond Road, Elwood, Suburb=Elwood
# Found supermarket page: https://www.travelvictoria.com.au/fitzroy/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/fitzroy/supermarkets/
# Page Title: Fitzroy supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Aldi, Address=247 Johnston Street, Fitzroy, Suburb=Fitzroy
# Found Supermarket: Name=Coles, Address=95-103 Johnston Street, Fitzroy, Suburb=Fitzroy
# Found Supermarket: Name=Coles, Address=170 Smith Street, Collingwood, Suburb=Collingwood
# Found Supermarket: Name=FoodWorks, Address=168-170 Brunswick Street, Fitzroy, Suburb=Fitzroy
# Found Supermarket: Name=FoodWorks, Address=169 Gertrude Street, Fitzroy, Suburb=Fitzroy
# Found Supermarket: Name=IGA, Address=424-428 Brunswick Street, Fitzroy, Suburb=Fitzroy
# Found Supermarket: Name=IGA, Address=37-49A Best Street, Fitzroy North, Suburb=Fitzroy North
# Found Supermarket: Name=Woolworths, Address=243 Smith Street, Fitzroy, Suburb=Fitzroy
# Found Supermarket: Name=Woolworths, Address=377 Smith Street, Fitzroy, Suburb=Fitzroy
# Found supermarket page: https://www.travelvictoria.com.au/hampton/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/hampton/supermarkets/
# Page Title: Hampton supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Coles, Address=361 Bluff Road, Hampton, Suburb=Hampton
# Found Supermarket: Name=IGA, Address=547-551 Hampton Street, Hampton, Suburb=Hampton
# Found Supermarket: Name=Woolworths, Address=355-363 Hampton Street, Hampton, Suburb=Hampton
# Found supermarket page: https://www.travelvictoria.com.au/mooneeponds/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/mooneeponds/supermarkets/
# Page Title: Moonee Ponds supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Aldi, Address=Moonee Ponds Central, 14-16 Hall Street, Moonee Ponds, Suburb=Moonee Ponds
# Found Supermarket: Name=Coles, Address=Moonee Ponds Central, 20 Homer Street, Moonee Ponds, Suburb=Moonee Ponds
# Found Supermarket: Name=IGA, Address=118-124 Maribyrnong Road, Moonee Ponds, Suburb=Moonee Ponds
# Found Supermarket: Name=Woolworths, Address=13-15 Pratt Street, Moonee Ponds, Suburb=Moonee Ponds
# Found supermarket page: https://www.travelvictoria.com.au/northmelbourne/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/northmelbourne/supermarkets/
# Page Title: North Melbourne supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Friendly Grocer, Address=549 Queensberry Street, North Melbourne, Suburb=North Melbourne
# Found Supermarket: Name=IGA, Address=20-26 Errol Street, North Melbourne, Suburb=North Melbourne
# Found Supermarket: Name=IGA, Address=75 Flemington Road, North Melbourne, Suburb=North Melbourne
# Found Supermarket: Name=IGA, Address=23 Melrose Street, North Melbourne, Suburb=North Melbourne
# Found Supermarket: Name=Woolworths, Address=Arden Gardens, 101-133 Canning Street, North Melbourne, Suburb=North Melbourne
# Found supermarket page: https://www.travelvictoria.com.au/parkville/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/parkville/supermarkets/
# Page Title: Parkville supermarkets - Travel Victoria: accommodation & visitor guide
# Found supermarket page: https://www.travelvictoria.com.au/portmelbourne/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/portmelbourne/supermarkets/
# Page Title: Port Melbourne supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Coles, Address=203 Bay Street, Port Melbourne, Suburb=Port Melbourne
# Found Supermarket: Name=Go To Grocer, Address=120 Bay Street, Port Melbourne, Suburb=Port Melbourne
# Found Supermarket: Name=IGA, Address=78 Bay Street, Port Melbourne, Suburb=Port Melbourne
# Found Supermarket: Name=Woolworths, Address=477-481 Plummer Street, Port Melbourne, Suburb=Port Melbourne
# Found supermarket page: https://www.travelvictoria.com.au/richmond/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/richmond/supermarkets/
# Page Title: Richmond supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Aldi, Address=The Hive, 313 Victoria Street, Abbotsford, Suburb=Abbotsford
# Found Supermarket: Name=Coles, Address=Richmond Traders, 261-271 Bridge Road, Richmond, Suburb=Richmond
# Found Supermarket: Name=Coles, Address=Victoria Gardens, 620 Victoria Street, Richmond, Suburb=Richmond
# Found Supermarket: Name=Coles, Address=150 Swan Street, Cremorne, Suburb=Cremorne
# Found Supermarket: Name=IGA, Address=518-524 Bridge Road, Richmond, Suburb=Richmond
# Found Supermarket: Name=IGA, Address=609 Victoria Street, Abbotsford, Suburb=Abbotsford
# Found Supermarket: Name=IGA, Address=160 Cremorne Street, Cremorne, Suburb=Cremorne
# Found Supermarket: Name=Woolworths, Address=The Hive, 313 Victoria Street, Abbotsford, Suburb=Abbotsford
# Found supermarket page: https://www.travelvictoria.com.au/sandringham/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/sandringham/supermarkets/
# Page Title: Sandringham supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Coles, Address=10-20 Waltham Street, Sandringham, Suburb=Sandringham
# Found Supermarket: Name=IGA, Address=Sandy Hill, 222 Bay Road, Sandringham, Suburb=Sandringham
# Found supermarket page: https://www.travelvictoria.com.au/southbank/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/southbank/supermarkets/
# Page Title: Southbank supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Aldi, Address=100 Market Street, Southbank, Suburb=Southbank
# Found Supermarket: Name=FoodWorks, Address=180 City Road, Southbank, Suburb=Southbank
# Found Supermarket: Name=IGA, Address=89-91 City Road, Southbank, Suburb=Southbank
# Found Supermarket: Name=IGA, Address=42-44 Clarendon Street, Southbank, Suburb=Southbank
# Found Supermarket: Name=IGA, Address=6 Freshwater Place, Southbank, Suburb=Southbank
# Found Supermarket: Name=IGA, Address=320 St Kilda Road, Southbank, Suburb=Southbank
# Found Supermarket: Name=IGA, Address=151 Sturt Street, Southbank, Suburb=Southbank
# Found Supermarket: Name=Woolworths, Address=263 City Road, Southbank, Suburb=Southbank
# Found Supermarket: Name=Woolworths, Address=Melbourne Square, 10 Hoff Boulevard, Southbank, Suburb=Southbank
# Found supermarket page: https://www.travelvictoria.com.au/southmelbourne/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/southmelbourne/supermarkets/
# Page Title: South Melbourne supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Coles, Address=Clarendon Centre, 261 Clarendon Street, South Melbourne, Suburb=South Melbourne
# Found Supermarket: Name=Coles, Address=253-273 Normanby Road, South Melbourne, Suburb=South Melbourne
# Found Supermarket: Name=IGA, Address=36-38 Park Street, South Melbourne, Suburb=South Melbourne
# Found Supermarket: Name=Woolworths, Address=South Melbourne Central, 113 Cecil Street, South Melbourne, Suburb=South Melbourne
# Found supermarket page: https://www.travelvictoria.com.au/southyarra/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/southyarra/supermarkets/
# Page Title: South Yarra supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Aldi, Address=34 Elizabeth Street, South Yarra, Suburb=South Yarra
# Found Supermarket: Name=Coles, Address=303 Chapel Street, Prahran, Suburb=Prahran
# Found Supermarket: Name=IGA, Address=113-115 Toorak Road, South Yarra, Suburb=South Yarra
# Found Supermarket: Name=IGA, Address=172-174 Toorak Road, South Yarra, Suburb=South Yarra
# Found Supermarket: Name=Woolworths, Address=670 Chapel Shopping Centre, 670 Chapel Street, South Yarra, Suburb=South Yarra
# Found Supermarket: Name=Woolworths, Address=1-9 Wattle Street, Prahran, Suburb=Prahran
# Found supermarket page: https://www.travelvictoria.com.au/stkilda/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/stkilda/supermarkets/
# Page Title: St Kilda supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Aldi, Address=135 Inkerman Street, St Kilda, Suburb=St Kilda
# Found Supermarket: Name=Coles, Address=Acland Court, 181-189 Barkly Street, St Kilda, Suburb=St Kilda
# Found Supermarket: Name=Coles, Address=54 Camden Street, Balaclava, Suburb=Balaclava
# Found Supermarket: Name=Woolworths, Address=117 Acland Street, St Kilda, Suburb=St Kilda
# Found Supermarket: Name=Woolworths, Address=64 Fitzroy Street, St Kilda, Suburb=St Kilda
# Found Supermarket: Name=Woolworths, Address=220 Carlisle Street, Balaclava, Suburb=Balaclava
# Found supermarket page: https://www.travelvictoria.com.au/tooradin/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/tooradin/supermarkets/
# Page Title: Tooradin supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=FoodWorks, Address=104 South Gippsland Highway, Tooradin, Suburb=Tooradin
# Found supermarket page: https://www.travelvictoria.com.au/werribee/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/werribee/supermarkets/
# Page Title: Werribee supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Aldi, Address=77-83 Synnot Street, Werribee, Suburb=Werribee
# Found Supermarket: Name=Aldi, Address=Pacific Werribee, Heaths Road, Hoppers Crossing, Suburb=Hoppers Crossing
# Found Supermarket: Name=Coles, Address=143 Watton Street, Werribee, Suburb=Werribee
# Found Supermarket: Name=Coles, Address=Pacific Werribee, Heaths Road, Hoppers Crossing, Suburb=Hoppers Crossing
# Found Supermarket: Name=FoodWorks, Address=92-94 Cottrell Street, Werribee, Suburb=Werribee
# Found Supermarket: Name=IGA, Address=167-179 Shaws Road, Werribee, Suburb=Werribee
# Found Supermarket: Name=Woolworths, Address=2 Watton Street, Werribee, Suburb=Werribee
# Found Supermarket: Name=Woolworths, Address=Pacific Werribee, Heaths Road, Hoppers Crossing, Suburb=Hoppers Crossing
# Found supermarket page: https://www.travelvictoria.com.au/williamstown/supermarkets/
# Visiting supermarket page: https://www.travelvictoria.com.au/williamstown/supermarkets/
# Page Title: Williamstown supermarkets - Travel Victoria: accommodation & visitor guide
# Found Supermarket: Name=Coles, Address=29 Douglas Parade, Williamstown, Suburb=Williamstown
# Found Supermarket: Name=Woolworths, Address=71 Kororoit Creek Road, Williamstown, Suburb=Williamstown
# Supermarkets information has been saved to '../../data/landing/Supermarkets/supermarkets_info.parquet'

# %%
# Create geolocator object
geolocator = Nominatim(user_agent="supermarket_postcode_lookup")

# Function to simplify the address, keeping only street and city
def simplify_address(address):
    # Use regex to remove the part before the comma (usually mall name or other unnecessary info)
    simplified = re.sub(r'^[^,]+,\s*', '', address)
    return simplified

# Use geopy to get the postcode from the address
def get_postcode_from_geopy(address, retries=3):
    for attempt in range(retries):
        try:
            print(f"Fetching address: {address}")
            location = geolocator.geocode(address)
            if location:
                location_details = geolocator.reverse((location.latitude, location.longitude), exactly_one=True)
                address_info = location_details.raw.get('address', {})
                postcode = address_info.get('postcode', 'No postcode found')
                return postcode
            print(f"Postal code not found for address: {address}")
            return None
        except Exception as e:
            print(f"Error fetching data for address: {address}. Attempt {attempt + 1} of {retries}")
            time.sleep(2)  # Wait for 2 seconds before retrying
    return None

# Read the Parquet file and query the postcode for each address
def add_postcode_to_parquet(input_file, output_file):
    # Read the original Parquet file into a DataFrame
    df = pd.read_parquet(input_file)
    
    # Add a new 'Postcode' column
    df['Postcode'] = None

    # Iterate through each row of data
    for index, row in df.iterrows():
        address = row['Address']  # Assuming 'Address' column exists

        # Step 1: Use geopy to query the postcode
        postcode = get_postcode_from_geopy(address)
        
        # Step 2: If the original address query fails, simplify the address and retry
        if not postcode or postcode == "No postcode found":
            simplified_address = simplify_address(address)
            print(f"Original address failed, trying simplified address: {simplified_address}")
            postcode = get_postcode_from_geopy(simplified_address)
        
        # Update the 'Postcode' column with the found postcode
        df.at[index, 'Postcode'] = postcode
        time.sleep(1)  # Wait 1 second after each query to avoid sending requests too quickly

    # Save the updated data to a new Parquet file
    df.to_parquet(output_file, index=False, engine='pyarrow')

# File paths
input_file = '../../data/landing/Supermarkets/supermarkets_info.parquet'  # Input file path
output_file = '../../data/landing/Supermarkets/supermarkets_with_postcode.parquet'  # Output file path

# Call the function
add_postcode_to_parquet(input_file, output_file)

print(f"Updated Parquet file with postcodes has been saved to {output_file}")
# Out:
# Fetching address: 8 Franklin Street, Melbourne
# Fetching address: 2 Elizabeth Street, Melbourne
# Fetching address: Melbourne Central, 183-201 La Trobe Street, Melbourne
# Postal code not found for address: Melbourne Central, 183-201 La Trobe Street, Melbourne
# Original address failed, trying simplified address: 183-201 La Trobe Street, Melbourne
# Fetching address: 183-201 La Trobe Street, Melbourne
# Fetching address: Shop 1, 360 Collins Street, Melbourne
# Fetching address: 470 Collins Street, Melbourne
# Fetching address: 19 Commercial Road, Melbourne
# Fetching address: 333 Exhibition Street, Melbourne
# Fetching address: 84 Flinders Street, Melbourne
# Fetching address: 35-41 Lonsdale Street, Melbourne
# Fetching address: 85 Queen Street, Melbourne
# Fetching address: 600 Bourke Street, Melbourne
# Fetching address: 60 Elizabeth Street, Melbourne
# Fetching address: 388 Elizabeth Street, Melbourne
# Fetching address: 611 Elizabeth Street, Melbourne
# Fetching address: 222 Exhibition Street, Melbourne
# Fetching address: 262 Flinders Street, Melbourne
# Fetching address: QV, 210 Lonsdale Street, Melbourne
# Fetching address: 374 Queen Street, Melbourne
# Fetching address: 189 Victoria Avenue, Albert Park
# Fetching address: 133 Dundas Place, Albert Park
# Fetching address: 163 Mills Street, Albert Park
# Fetching address: 95-97 Dundas Place, Albert Park
# Fetching address: 346-348 Balcombe Road, Beaumaris
# Fetching address: 7A Keys Street, Beaumaris
# Fetching address: 6-12 South Concourse, Beaumaris
# Fetching address: Eden Rise, 1 O'Shea Road, Berwick
# Postal code not found for address: Eden Rise, 1 O'Shea Road, Berwick
# Original address failed, trying simplified address: 1 O'Shea Road, Berwick
# Fetching address: 1 O'Shea Road, Berwick
# Fetching address: 2 Richardson Grove, Berwick
# Fetching address: Eden Rise, 1 O'Shea Road, Berwick
# Postal code not found for address: Eden Rise, 1 O'Shea Road, Berwick
# Original address failed, trying simplified address: 1 O'Shea Road, Berwick
# Fetching address: 1 O'Shea Road, Berwick
# Fetching address: Parkhill Plaza, 215-225 Parkhill Drive, Berwick
# Postal code not found for address: Parkhill Plaza, 215-225 Parkhill Drive, Berwick
# Original address failed, trying simplified address: 215-225 Parkhill Drive, Berwick
# Fetching address: 215-225 Parkhill Drive, Berwick
# Fetching address: Alira Village, 36 Adakite Drive, Berwick
# Postal code not found for address: Alira Village, 36 Adakite Drive, Berwick
# Original address failed, trying simplified address: 36 Adakite Drive, Berwick
# Fetching address: 36 Adakite Drive, Berwick
# Postal code not found for address: 36 Adakite Drive, Berwick
# Fetching address: Berwick Marketplace, 1-9 Lyall Road, Berwick
# Postal code not found for address: Berwick Marketplace, 1-9 Lyall Road, Berwick
# Original address failed, trying simplified address: 1-9 Lyall Road, Berwick
# Fetching address: 1-9 Lyall Road, Berwick
# Fetching address: 26-34 Church Street, Brighton
# Error fetching data for address: 26-34 Church Street, Brighton. Attempt 1 of 3
# Fetching address: 26-34 Church Street, Brighton
# Error fetching data for address: 26-34 Church Street, Brighton. Attempt 2 of 3
# Fetching address: 26-34 Church Street, Brighton
# Error fetching data for address: 26-34 Church Street, Brighton. Attempt 3 of 3
# Original address failed, trying simplified address: Brighton
# Fetching address: Brighton
# Fetching address: 380 Bay Street, Brighton
# Fetching address: 116-122 Were Street, Brighton
# Fetching address: 10 Cochrane Street, Brighton
# Fetching address: 765A Hawthorn Road, Brighton East
# Fetching address: 566 Hawthorn Road, Caulfield South
# Fetching address: 104 Church Street, Brighton
# Fetching address: 292-298 Sydney Road, Brunswick
# Fetching address: Barkly Square, 90-106 Sydney Road, Brunswick
# Fetching address: 127-137 Nicholson Street, Brunswick East
# Fetching address: Union Square, 190 Union Street, Brunswick West
# Postal code not found for address: Union Square, 190 Union Street, Brunswick West
# Original address failed, trying simplified address: 190 Union Street, Brunswick West
# Fetching address: 190 Union Street, Brunswick West
# Fetching address: 870 Sydney Road, Brunswick
# Fetching address: 474 Lygon Street, Brunswick East
# Fetching address: 52 Melville Road, Brunswick West
# Fetching address: 25 Nicholson Street, Brunswick East
# Fetching address: 1-9 Lygon Street, Brunswick
# Fetching address: 614 Sydney Road, Brunswick
# Fetching address: 21 Brunswick Road, Brunswick East
# Fetching address: 326-328 Lygon Street, Brunswick East
# Fetching address: 360 Moreland Road, Brunswick West
# Fetching address: 2-6 Olive York Way, Brunswick West
# Fetching address: 300-304 Albert Street, Brunswick
# Fetching address: Barkly Square, 90-106 Sydney Road, Brunswick
# Fetching address: 808 Sydney Road, Brunswick
# Fetching address: 799 Nicholson Street, Carlton North
# Fetching address: 109 Lygon Street, Carlton
# Fetching address: Lygon Court, 368-384 Lygon Street, Carlton
# Fetching address: 199 Thames Promenade, Chelsea Heights
# Fetching address: 31-33 Bath Street, Chelsea
# Error fetching data for address: 31-33 Bath Street, Chelsea. Attempt 1 of 3
# Fetching address: 31-33 Bath Street, Chelsea
# Error fetching data for address: 31-33 Bath Street, Chelsea. Attempt 2 of 3
# Fetching address: 31-33 Bath Street, Chelsea
# Fetching address: 14-20 Bakewell Street, Cranbourne
# Fetching address: Hunt Club Village, 1 Linsell Boulevard, Cranbourne East
# Postal code not found for address: Hunt Club Village, 1 Linsell Boulevard, Cranbourne East
# Original address failed, trying simplified address: 1 Linsell Boulevard, Cranbourne East
# Fetching address: 1 Linsell Boulevard, Cranbourne East
# Fetching address: 51 Hamersley Drive, Clyde North
# Fetching address: Marriott Waters, 10-18 Society Avenue, Lyndhurst
# Postal code not found for address: Marriott Waters, 10-18 Society Avenue, Lyndhurst
# Original address failed, trying simplified address: 10-18 Society Avenue, Lyndhurst
# Fetching address: 10-18 Society Avenue, Lyndhurst
# Fetching address: Cranbourne Park Shopping Centre, High Street, Cranbourne
# Postal code not found for address: Cranbourne Park Shopping Centre, High Street, Cranbourne
# Original address failed, trying simplified address: High Street, Cranbourne
# Fetching address: High Street, Cranbourne
# Fetching address: Springhill, 1370 Thompsons Road, Cranbourne
# Fetching address: 95 Monahans Road, Cranbourne West
# Fetching address: Botanic Ridge Village, 10 Hummingbird Drive, Botanic Ridge
# Postal code not found for address: Botanic Ridge Village, 10 Hummingbird Drive, Botanic Ridge
# Original address failed, trying simplified address: 10 Hummingbird Drive, Botanic Ridge
# Fetching address: 10 Hummingbird Drive, Botanic Ridge
# Fetching address: Shopping On Clyde, 280 Berwick - Cranbourne Road, Clyde
# Postal code not found for address: Shopping On Clyde, 280 Berwick - Cranbourne Road, Clyde
# Original address failed, trying simplified address: 280 Berwick - Cranbourne Road, Clyde
# Fetching address: 280 Berwick - Cranbourne Road, Clyde
# Fetching address: Eve Central, 2-10 William Thwaites Boulevard, Cranbourne North
# Postal code not found for address: Eve Central, 2-10 William Thwaites Boulevard, Cranbourne North
# Original address failed, trying simplified address: 2-10 William Thwaites Boulevard, Cranbourne North
# Fetching address: 2-10 William Thwaites Boulevard, Cranbourne North
# Fetching address: Clarinda Village, 85 Everlasting Boulevard, Cranbourne West
# Postal code not found for address: Clarinda Village, 85 Everlasting Boulevard, Cranbourne West
# Original address failed, trying simplified address: 85 Everlasting Boulevard, Cranbourne West
# Fetching address: 85 Everlasting Boulevard, Cranbourne West
# Fetching address: Hunt Club Village, 1 Linsell Boulevard, Cranbourne East
# Postal code not found for address: Hunt Club Village, 1 Linsell Boulevard, Cranbourne East
# Original address failed, trying simplified address: 1 Linsell Boulevard, Cranbourne East
# Fetching address: 1 Linsell Boulevard, Cranbourne East
# Fetching address: The Avenue Village, 20 Linden Tree Way, Cranbourne North
# Error fetching data for address: The Avenue Village, 20 Linden Tree Way, Cranbourne North. Attempt 1 of 3
# Fetching address: The Avenue Village, 20 Linden Tree Way, Cranbourne North
# Error fetching data for address: The Avenue Village, 20 Linden Tree Way, Cranbourne North. Attempt 2 of 3
# Fetching address: The Avenue Village, 20 Linden Tree Way, Cranbourne North
# Error fetching data for address: The Avenue Village, 20 Linden Tree Way, Cranbourne North. Attempt 3 of 3
# Original address failed, trying simplified address: 20 Linden Tree Way, Cranbourne North
# Fetching address: 20 Linden Tree Way, Cranbourne North
# Fetching address: Thompson Parkway, 1085 South Gippsland Highway, Cranbourne North
# Postal code not found for address: Thompson Parkway, 1085 South Gippsland Highway, Cranbourne North
# Original address failed, trying simplified address: 1085 South Gippsland Highway, Cranbourne North
# Fetching address: 1085 South Gippsland Highway, Cranbourne North
# Fetching address: 19 Strathlea Drive, Cranbourne West
# Fetching address: Selandra Rise, 2 Selandra Boulevard, Clyde North
# Postal code not found for address: Selandra Rise, 2 Selandra Boulevard, Clyde North
# Original address failed, trying simplified address: 2 Selandra Boulevard, Clyde North
# Fetching address: 2 Selandra Boulevard, Clyde North
# Fetching address: Marriott Waters, 10-18 Society Avenue, Lyndhurst
# Postal code not found for address: Marriott Waters, 10-18 Society Avenue, Lyndhurst
# Original address failed, trying simplified address: 10-18 Society Avenue, Lyndhurst
# Fetching address: 10-18 Society Avenue, Lyndhurst
# Fetching address: Croydon Central, 5 Kent Avenue, Croydon
# Fetching address: Croydon Central, 15 Kent Avenue, Croydon
# Fetching address: 434 Maroondah Highway, Croydon
# Fetching address: 401-415 Maroondah Highway, Croydon North
# Fetching address: 13 The Mall, Croydon South
# Fetching address: Arndale Civic, 224-238 Mount Dandenong Road, Croydon
# Fetching address: Dandenong Square, 23-55 McCrae Street, Dandenong
# Postal code not found for address: Dandenong Square, 23-55 McCrae Street, Dandenong
# Original address failed, trying simplified address: 23-55 McCrae Street, Dandenong
# Fetching address: 23-55 McCrae Street, Dandenong
# Fetching address: Dandenong Square, 23-55 McCrae Street, Dandenong
# Postal code not found for address: Dandenong Square, 23-55 McCrae Street, Dandenong
# Original address failed, trying simplified address: 23-55 McCrae Street, Dandenong
# Fetching address: 23-55 McCrae Street, Dandenong
# Fetching address: 23-26 Princes Highway, Dandenong
# Fetching address: 42-44 Brady Road, Dandenong North
# Fetching address: 52-54 Menzies Avenue, Dandenong North
# Fetching address: 78-84 Hemmings Street, Dandenong
# Fetching address: 1-3 Gladstone Road, Dandenong
# Fetching address: Dandenong Square, 23-55 McCrae Street, Dandenong
# Postal code not found for address: Dandenong Square, 23-55 McCrae Street, Dandenong
# Original address failed, trying simplified address: 23-55 McCrae Street, Dandenong
# Fetching address: 23-55 McCrae Street, Dandenong
# Fetching address: 14 Hartnett Way, Dandenong South
# Fetching address: Spencer Outlet Centre, 201 Spencer Street, Docklands
# Fetching address: 381 Footscray Road, Docklands
# Fetching address: 20 Rakaia Way, Docklands
# Fetching address: 54 River Esplanade, Docklands
# Fetching address: Collins Square, 727 Collins Street, Docklands
# Fetching address: 63-93 Merchant Street, Docklands
# Fetching address: Southern Cross Station, 99 Spencer Street, Docklands
# Fetching address: The District Docklands, 90 Waterfront Way, Docklands
# Postal code not found for address: The District Docklands, 90 Waterfront Way, Docklands
# Original address failed, trying simplified address: 90 Waterfront Way, Docklands
# Fetching address: 90 Waterfront Way, Docklands
# Fetching address: 416-446 Victoria Parade, East Melbourne
# Postal code not found for address: 416-446 Victoria Parade, East Melbourne
# Original address failed, trying simplified address: East Melbourne
# Fetching address: East Melbourne
# Fetching address: 109 Ormond Road, Elwood
# Fetching address: 247 Johnston Street, Fitzroy
# Fetching address: 95-103 Johnston Street, Fitzroy
# Fetching address: 170 Smith Street, Collingwood
# Fetching address: 168-170 Brunswick Street, Fitzroy
# Fetching address: 169 Gertrude Street, Fitzroy
# Fetching address: 424-428 Brunswick Street, Fitzroy
# Fetching address: 37-49A Best Street, Fitzroy North
# Fetching address: 243 Smith Street, Fitzroy
# Fetching address: 377 Smith Street, Fitzroy
# Fetching address: 361 Bluff Road, Hampton
# Fetching address: 547-551 Hampton Street, Hampton
# Fetching address: 355-363 Hampton Street, Hampton
# Fetching address: Moonee Ponds Central, 14-16 Hall Street, Moonee Ponds
# Postal code not found for address: Moonee Ponds Central, 14-16 Hall Street, Moonee Ponds
# Original address failed, trying simplified address: 14-16 Hall Street, Moonee Ponds
# Fetching address: 14-16 Hall Street, Moonee Ponds
# Fetching address: Moonee Ponds Central, 20 Homer Street, Moonee Ponds
# Postal code not found for address: Moonee Ponds Central, 20 Homer Street, Moonee Ponds
# Original address failed, trying simplified address: 20 Homer Street, Moonee Ponds
# Fetching address: 20 Homer Street, Moonee Ponds
# Fetching address: 118-124 Maribyrnong Road, Moonee Ponds
# Fetching address: 13-15 Pratt Street, Moonee Ponds
# Fetching address: 549 Queensberry Street, North Melbourne
# Fetching address: 20-26 Errol Street, North Melbourne
# Fetching address: 75 Flemington Road, North Melbourne
# Fetching address: 23 Melrose Street, North Melbourne
# Fetching address: Arden Gardens, 101-133 Canning Street, North Melbourne
# Postal code not found for address: Arden Gardens, 101-133 Canning Street, North Melbourne
# Original address failed, trying simplified address: 101-133 Canning Street, North Melbourne
# Fetching address: 101-133 Canning Street, North Melbourne
# Fetching address: 203 Bay Street, Port Melbourne
# Fetching address: 120 Bay Street, Port Melbourne
# Fetching address: 78 Bay Street, Port Melbourne
# Fetching address: 477-481 Plummer Street, Port Melbourne
# Fetching address: The Hive, 313 Victoria Street, Abbotsford
# Fetching address: Richmond Traders, 261-271 Bridge Road, Richmond
# Postal code not found for address: Richmond Traders, 261-271 Bridge Road, Richmond
# Original address failed, trying simplified address: 261-271 Bridge Road, Richmond
# Fetching address: 261-271 Bridge Road, Richmond
# Fetching address: Victoria Gardens, 620 Victoria Street, Richmond
# Postal code not found for address: Victoria Gardens, 620 Victoria Street, Richmond
# Original address failed, trying simplified address: 620 Victoria Street, Richmond
# Fetching address: 620 Victoria Street, Richmond
# Fetching address: 150 Swan Street, Cremorne
# Fetching address: 518-524 Bridge Road, Richmond
# Fetching address: 609 Victoria Street, Abbotsford
# Fetching address: 160 Cremorne Street, Cremorne
# Fetching address: The Hive, 313 Victoria Street, Abbotsford
# Fetching address: 10-20 Waltham Street, Sandringham
# Fetching address: Sandy Hill, 222 Bay Road, Sandringham
# Postal code not found for address: Sandy Hill, 222 Bay Road, Sandringham
# Original address failed, trying simplified address: 222 Bay Road, Sandringham
# Fetching address: 222 Bay Road, Sandringham
# Fetching address: 100 Market Street, Southbank
# Fetching address: 180 City Road, Southbank
# Fetching address: 89-91 City Road, Southbank
# Fetching address: 42-44 Clarendon Street, Southbank
# Fetching address: 6 Freshwater Place, Southbank
# Fetching address: 320 St Kilda Road, Southbank
# Fetching address: 151 Sturt Street, Southbank
# Fetching address: 263 City Road, Southbank
# Fetching address: Melbourne Square, 10 Hoff Boulevard, Southbank
# Postal code not found for address: Melbourne Square, 10 Hoff Boulevard, Southbank
# Original address failed, trying simplified address: 10 Hoff Boulevard, Southbank
# Fetching address: 10 Hoff Boulevard, Southbank
# Fetching address: Clarendon Centre, 261 Clarendon Street, South Melbourne
# Fetching address: 253-273 Normanby Road, South Melbourne
# Postal code not found for address: 253-273 Normanby Road, South Melbourne
# Original address failed, trying simplified address: South Melbourne
# Fetching address: South Melbourne
# Fetching address: 36-38 Park Street, South Melbourne
# Error fetching data for address: 36-38 Park Street, South Melbourne. Attempt 1 of 3
# Fetching address: 36-38 Park Street, South Melbourne
# Error fetching data for address: 36-38 Park Street, South Melbourne. Attempt 2 of 3
# Fetching address: 36-38 Park Street, South Melbourne
# Fetching address: South Melbourne Central, 113 Cecil Street, South Melbourne
# Fetching address: 34 Elizabeth Street, South Yarra
# Fetching address: 303 Chapel Street, Prahran
# Fetching address: 113-115 Toorak Road, South Yarra
# Fetching address: 172-174 Toorak Road, South Yarra
# Fetching address: 670 Chapel Shopping Centre, 670 Chapel Street, South Yarra
# Postal code not found for address: 670 Chapel Shopping Centre, 670 Chapel Street, South Yarra
# Original address failed, trying simplified address: 670 Chapel Street, South Yarra
# Fetching address: 670 Chapel Street, South Yarra
# Fetching address: 1-9 Wattle Street, Prahran
# Fetching address: 135 Inkerman Street, St Kilda
# Fetching address: Acland Court, 181-189 Barkly Street, St Kilda
# Postal code not found for address: Acland Court, 181-189 Barkly Street, St Kilda
# Original address failed, trying simplified address: 181-189 Barkly Street, St Kilda
# Fetching address: 181-189 Barkly Street, St Kilda
# Fetching address: 54 Camden Street, Balaclava
# Fetching address: 117 Acland Street, St Kilda
# Fetching address: 64 Fitzroy Street, St Kilda
# Fetching address: 220 Carlisle Street, Balaclava
# Fetching address: 104 South Gippsland Highway, Tooradin
# Fetching address: 77-83 Synnot Street, Werribee
# Fetching address: Pacific Werribee, Heaths Road, Hoppers Crossing
# Fetching address: 143 Watton Street, Werribee
# Fetching address: Pacific Werribee, Heaths Road, Hoppers Crossing
# Fetching address: 92-94 Cottrell Street, Werribee
# Fetching address: 167-179 Shaws Road, Werribee
# Fetching address: 2 Watton Street, Werribee
# Fetching address: Pacific Werribee, Heaths Road, Hoppers Crossing
# Fetching address: 29 Douglas Parade, Williamstown
# Fetching address: 71 Kororoit Creek Road, Williamstown
# Updated Parquet file with postcodes has been saved to ../../data/landing/Supermarkets/supermarkets_with_postcode.parquet
